# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
hindustan=yf.download('HINDUNILVR.NS',start='2023-04-01',end='2024-03-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
hindustan.to_csv('hindustan.csv')

# %%
hindustan=pd.read_csv('hindustan.csv')

# %%
hindustan
# Out:
#            Date         Open         High          Low        Close  \
# 0    2023-04-03  2570.000000  2570.000000  2515.050049  2536.100098
# 1    2023-04-05  2512.500000  2588.550049  2502.000000  2582.750000
# 2    2023-04-06  2575.000000  2585.000000  2553.000000  2565.250000
# 3    2023-04-10  2565.250000  2568.949951  2525.000000  2532.149902
# 4    2023-04-11  2540.000000  2555.000000  2533.000000  2547.750000
# ..          ...          ...          ...          ...          ...
# 238  2024-03-21  2234.000000  2259.149902  2234.000000  2242.350098
# 239  2024-03-22  2239.050049  2266.000000  2232.050049  2256.550049
# 240  2024-03-26  2232.100098  2259.149902  2232.000000  2240.000000
# 241  2024-03-27  2250.000000  2263.000000  2236.000000  2239.699951
# 242  2024-03-28  2245.000000  2287.899902  2240.100098  2264.350098
#
#        Adj Close   Volume
# 0    2497.239502   918048
# 1    2543.174561  1489612
# 2    2525.942627   797414
# 3    2493.349854   853322
# ...

# %%
hindustan['Moving_Average']=hindustan['Close'].rolling(window=20).mean()

# %%
hindustan.plot.line(x='Date',y=['Close','Moving_Average'])
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #
# Code For 10-Days SMA

# %%
moving_avg=[]
for i in range(243):
    if i<9:
        moving_avg.append(float('NaN'))
    else:
        average=sum(hindustan['Close'].iloc[i-9:i+1])/10
        moving_avg.append(average)

hindustan['SMA_10']=pd.DataFrame(moving_avg)

# %%
hindustan
# Out:
#            Date         Open         High          Low        Close  \
# 0    2023-04-03  2570.000000  2570.000000  2515.050049  2536.100098
# 1    2023-04-05  2512.500000  2588.550049  2502.000000  2582.750000
# 2    2023-04-06  2575.000000  2585.000000  2553.000000  2565.250000
# 3    2023-04-10  2565.250000  2568.949951  2525.000000  2532.149902
# 4    2023-04-11  2540.000000  2555.000000  2533.000000  2547.750000
# ..          ...          ...          ...          ...          ...
# 238  2024-03-21  2234.000000  2259.149902  2234.000000  2242.350098
# 239  2024-03-22  2239.050049  2266.000000  2232.050049  2256.550049
# 240  2024-03-26  2232.100098  2259.149902  2232.000000  2240.000000
# 241  2024-03-27  2250.000000  2263.000000  2236.000000  2239.699951
# 242  2024-03-28  2245.000000  2287.899902  2240.100098  2264.350098
#
#        Adj Close   Volume  Moving_Average       SMA_10
# 0    2497.239502   918048             NaN          NaN
# ...

# %%
hindustan.plot.line(x='Date', y=['Close', 'Moving_Average', 'SMA_10'], figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>
